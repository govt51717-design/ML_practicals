# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,classification_report

# %%
df = pd.read_csv('updated_customer_data1.csv')
df.head()
# Out:
#    age  income  purchase_amount  satisfaction_score
# 0   27   40682            18249                   6
# 1   29   15317             4557                   6
# 2   37   38849            11822                   6
# 3   30   11568             4098                   7
# 4   31   46952            19685                   5

# %%
print(df.info())
print(df.describe())
print(df.isnull().sum())
print(df.duplicated().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 4 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   age                 100000 non-null  int64
#  1   income              100000 non-null  int64
#  2   purchase_amount     100000 non-null  int64
#  3   satisfaction_score  100000 non-null  int64
# dtypes: int64(4)
# memory usage: 3.1 MB
# None
#                  age         income  purchase_amount  satisfaction_score
# count  100000.000000  100000.000000    100000.000000       100000.000000
# mean       30.003260   27516.269880      9634.790840            5.009650
# std         4.480535   12996.782587      4799.339449            1.038714
# min        12.000000    5000.000000      1118.000000            0.000000
# 25%        27.000000   16271.750000      5583.000000            4.000000
# 50%        30.000000   27584.500000      9452.000000            5.000000
# 75%        33.000000   38747.250000     13350.000000            6.000000
# max        49.000000   50000.000000     26204.000000           10.000000
# age                   0
# income                0
# purchase_amount       0
# satisfaction_score    0
# dtype: int64
# 0

# %%
X = df.drop('satisfaction_score',axis=1)
y = df['satisfaction_score']

# %%
# scaler = StandardScaler()
# X = scaler.fit_transform(X)
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = KNeighborsClassifier(n_neighbors=1)
model3 = KNeighborsClassifier(n_neighbors=3)
model5 = KNeighborsClassifier(n_neighbors=5)

# %%
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
model3.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
model5.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = model.predict(X_test)
y_pred3 = model3.predict(X_test)
y_pred5 = model5.predict(X_test)

# %%
print("accuracy_score :", accuracy_score(y_test, y_pred))

print("precision :", precision_score(y_test, y_pred, average='weighted'))

print("recall :", recall_score(y_test, y_pred, average='weighted'))

print("f1_score :", f1_score(y_test, y_pred, average='weighted'))

print(classification_report(y_test, y_pred))
# Out:
# accuracy_score : 0.2725
# precision : 0.2723661457564591
# recall : 0.2725
# f1_score : 0.2724127992504216
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         4
#            2       0.01      0.01      0.01       110
#            3       0.06      0.06      0.06      1240
#            4       0.24      0.25      0.25      4748
#            5       0.39      0.39      0.39      7652
#            6       0.24      0.23      0.24      4925
#            7       0.06      0.06      0.06      1188
#            8       0.00      0.00      0.00       124
#            9       0.00      0.00      0.00         8
#           10       0.00      0.00      0.00         1
#
#     accuracy                           0.27     20000
#    macro avg       0.09      0.09      0.09     20000
# weighted avg       0.27      0.27      0.27     20000
# c:\Users\user\OneDrive\Desktop\ML\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\user\OneDrive\Desktop\ML\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\user\OneDrive\Desktop\ML\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\user\OneDrive\Desktop\ML\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\user\OneDrive\Desktop\ML\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\user\OneDrive\Desktop\ML\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\user\OneDrive\Desktop\ML\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\user\OneDrive\Desktop\ML\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
print("accuracy_score :", accuracy_score(y_test, y_pred3))

print("precision :", precision_score(y_test, y_pred3, average='weighted'))

print("recall :", recall_score(y_test, y_pred3, average='weighted'))

print("f1_score :", f1_score(y_test, y_pred3, average='weighted'))

print(classification_report(y_test, y_pred3))
# Out:
# accuracy_score : 0.27035
# precision : 0.27543095812038515
# recall : 0.27035
# f1_score : 0.2663229136995421
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         4
#            2       0.00      0.01      0.01       110
#            3       0.06      0.12      0.08      1240
#            4       0.24      0.34      0.28      4748
#            5       0.39      0.37      0.38      7652
#            6       0.25      0.15      0.19      4925
#            7       0.05      0.01      0.02      1188
#            8       0.00      0.00      0.00       124
#            9       0.00      0.00      0.00         8
#           10       0.00      0.00      0.00         1
#
#     accuracy                           0.27     20000
#    macro avg       0.09      0.09      0.09     20000
# weighted avg       0.28      0.27      0.27     20000
# c:\Users\user\OneDrive\Desktop\ML\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\user\OneDrive\Desktop\ML\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\user\OneDrive\Desktop\ML\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\user\OneDrive\Desktop\ML\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\user\OneDrive\Desktop\ML\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\user\OneDrive\Desktop\ML\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\user\OneDrive\Desktop\ML\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\user\OneDrive\Desktop\ML\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
print("accuracy_score :", accuracy_score(y_test, y_pred5))

print("precision :", precision_score(y_test, y_pred5, average='weighted'))

print("recall :", recall_score(y_test, y_pred5, average='weighted'))

print("f1_score :", f1_score(y_test, y_pred5, average='weighted'))

print(classification_report(y_test, y_pred5))
# Out:
# accuracy_score : 0.301
# precision : 0.2726584656245671
# recall : 0.301
# f1_score : 0.27945011637410155
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         4
#            2       0.00      0.00      0.00       110
#            3       0.07      0.04      0.05      1240
#            4       0.24      0.30      0.27      4748
#            5       0.38      0.49      0.43      7652
#            6       0.25      0.16      0.19      4925
#            7       0.07      0.01      0.02      1188
#            8       0.00      0.00      0.00       124
#            9       0.00      0.00      0.00         8
#           10       0.00      0.00      0.00         1
#
#     accuracy                           0.30     20000
#    macro avg       0.10      0.10      0.10     20000
# weighted avg       0.27      0.30      0.28     20000
# c:\Users\user\OneDrive\Desktop\ML\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\user\OneDrive\Desktop\ML\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\user\OneDrive\Desktop\ML\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\user\OneDrive\Desktop\ML\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
results = pd.DataFrame({
    "k":[1,3,5],
    "Accuracy":[
        accuracy_score(y_test,y_pred),
        accuracy_score(y_test,y_pred3),
        accuracy_score(y_test,y_pred5)
    ]
})

print(results)
# Out:
#    k  Accuracy
# 0  1   0.27250
# 1  3   0.27035
# 2  5   0.30100

# %%
for k in [1,3,5,7,9,11,15]:
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    print("k =",k,"Accuracy =",accuracy_score(y_test,y_pred))
# Out:
# k = 1 Accuracy = 0.2725
# k = 3 Accuracy = 0.27035
# k = 5 Accuracy = 0.301
# k = 7 Accuracy = 0.3079
# k = 9 Accuracy = 0.31725
# k = 11 Accuracy = 0.32365
# k = 15 Accuracy = 0.33555
